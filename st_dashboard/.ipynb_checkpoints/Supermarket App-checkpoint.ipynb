# %%
import pandas as pd
import matplotlib.pyplot as ply
import numpy as np
import seaborn as sns

sns.set()
# %matplotlib inline

# %%
supermarket_df = pd.read_csv('supermarket.csv')
supermarket_df
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 0           1        1659             1961                   530        66490
# 1           2        1461             1752                   210        39820
# 2           3        1340             1609                   720        54010
# 3           4        1451             1748                   620        53730
# 4           5        1770             2111                   450        46620
# ..        ...         ...              ...                   ...          ...
# 891       892        1582             1910                  1080        66390
# 892       893        1387             1663                   850        82080
# 893       894        1200             1436                  1060        76440
# 894       895        1299             1560                   770        96610
# 895       896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
supermarket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store_id              896 non-null    int64
#  1   store_area            896 non-null    int64
#  2   items_available       896 non-null    int64
#  3   daily_customer_count  896 non-null    int64
#  4   store_sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
#changing store_id to data type str
supermarket_df.store_id = supermarket_df.store_id.astype(str)
supermarket_df.store_area = supermarket_df.store_area.astype(str)

# %%
supermarket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store_id              896 non-null    object
#  1   store_area            896 non-null    object
#  2   items_available       896 non-null    int64
#  3   daily_customer_count  896 non-null    int64
#  4   store_sales           896 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 35.1+ KB

# %%
supermarket_df.describe()
# Out:
#        items_available  daily_customer_count    store_sales
# count       896.000000            896.000000     896.000000
# mean       1782.035714            786.350446   59351.305804
# std         299.872053            265.389281   17190.741895
# min         932.000000             10.000000   14920.000000
# 25%        1575.500000            600.000000   46530.000000
# 50%        1773.500000            780.000000   58605.000000
# 75%        1982.750000            970.000000   71872.500000
# max        2667.000000           1560.000000  116320.000000

# %%
sns.boxplot(data=supermarket_df, x='items_available');

# %%
sns.boxplot(data=supermarket_df, x='daily_customer_count');

# %%
sns.boxplot(data=supermarket_df, x='store_sales');

# %%
#Top Stores
data = supermarket_df.sort_values(by='store_sales', ascending=False)
data
# Out:
#     store_id store_area  items_available  daily_customer_count  store_sales
# 649      650       1989             2414                   860       116320
# 868      869       1775             2104                   980       105150
# 432      433       1365             1638                   680       102920
# 408      409       1303             1587                  1310       102310
# 758      759       1486             1758                   820       101820
# ..       ...        ...              ...                   ...          ...
# 352      353       1397             1686                   850        21300
# 593      594       1624             1946                   870        20270
# 775      776       1537             1877                   660        17670
# 852      853       1477             1790                   880        16370
# 31        32       1250             1508                   990        14920
#
# [896 rows x 5 columns]

# %%
sns.scatterplot(data=data,x="items_available", y="store_sales");

# %%
sns.scatterplot(data=data,x="daily_customer_count", y="store_sales");
